# %%
name="sagara"
print(len(name))
# Out:
# 6

# %%
text="Akshay"
print(text[0:5])
# Out:
# Aksha

# %%
"kumar raja".upper()
# Out:
# 'KUMAR RAJA'

# %%
"KUMAR RAJA".lower()
# Out:
# 'kumar raja'

# %%
data="shashank"
print(data.strip())
# Out:
# shashank

# %%
email="user@gmail.com"
print("@.com"in email)
# Out:
# False

# %%
msg="i like c++"
print(msg.replace("c++","python"))
# Out:
# i like python

# %%
sentence="python is not easy"
words=sentence.split()
print(words)
# Out:
# ['python', 'is', 'not', 'easy']

# %%
words=["gaming","is","fun"]
print("".join(words))
# Out:
# gamingisfun

# %%
sentence="python is very easy"
words=sentence.rsplit()
print(words)
# Out:
# ['python', 'is', 'very', 'easy']

# %%
import builtins
name="akshay"
age=21
builtins.print(f"my name is {name} and I am {age} years old")
# Out:
# my name is akshay and I am 21 years old

# %%
url="https://example.com"
url.startswith("https")
# Out:
# True

# %%
file="data.csv"
file.endswith(".csr")
# Out:
# False

# %%
import builtins
text="alfalfa"
builtins.print(text.count("a"))
# Out:
# 3
